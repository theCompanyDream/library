# %%
import requests
import numpy

r = requests.get('https://data.cityofchicago.org/resource/cwig-ma7x.json')
r.json()
# Out:
# '[{"inspection_id":"2484890","dba_name":"WALMART NEIGHBORHOOD MARKET #3166","aka_name":"WALMART NEIGHBORHOOD MARKET #3166","license_":"2334925","facility_type":"Grocery Store","risk":"Risk 1 (High)","address":"4720 S COTTAGE GROVE AVE ","city":"CHICAGO","state":"IL","zip":"60615","inspection_date":"2021-02-18T00:00:00.000","inspection_type":"Complaint","results":"Pass","violations":"55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO CLEAN THE FLOORS IN WALK-IN COOLERS AND STORAGE AREAS WHERE NEEDED AND FLOOR DRAINS IN THE DELI PREP AREA.","latitude":"41.8089016636963","longitude":"-87.60669696618142","location":{"type":"Point","coordinates":[41.8089016636963,-87.60669696618142]}}\n,{"inspection_id":"2484892","dba_name":"MOBIL","aka_name":"MOBIL","license_":"2767226","facility_type":"Grocery Store","risk":"Risk 3 (Low)","address":"6000 S WESTERN AVE ","city":"CHICAGO","state":"IL","zip":"60636","inspection_date":"2021-02-18T00:00:00.000","inspection_type":
# ...
